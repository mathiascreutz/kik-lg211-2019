# %% [markdown]
# ### Tf-idf demo on the books in the Gutenberg corpus in NLTK
#
# Let's compute tf-idf scores for words occurring in the different books in the NLTK version of the Gutenberg corpus.
#
# First we take a look at what books there are and how many words each of them contains:

# %%
import nltk

booknames = nltk.corpus.gutenberg.fileids()

for name in booknames:
    print("{:s} contains {:d} word tokens.".format(name, len(nltk.corpus.gutenberg.words(name))))
# Out:
# austen-emma.txt contains 192427 word tokens.
# austen-persuasion.txt contains 98171 word tokens.
# austen-sense.txt contains 141576 word tokens.
# bible-kjv.txt contains 1010654 word tokens.
# blake-poems.txt contains 8354 word tokens.
# bryant-stories.txt contains 55563 word tokens.
# burgess-busterbrown.txt contains 18963 word tokens.
# carroll-alice.txt contains 34110 word tokens.
# chesterton-ball.txt contains 96996 word tokens.
# chesterton-brown.txt contains 86063 word tokens.
# chesterton-thursday.txt contains 69213 word tokens.
# edgeworth-parents.txt contains 210663 word tokens.
# melville-moby_dick.txt contains 260819 word tokens.
# milton-paradise.txt contains 96825 word tokens.
# shakespeare-caesar.txt contains 25833 word tokens.
# shakespeare-hamlet.txt contains 37360 word tokens.
# shakespeare-macbeth.txt contains 23140 word tokens.
# whitman-leaves.txt contains 154883 word tokens.

# %% [markdown]
# Let's have a look how many word tokens and types there are in all books combined.

# %%
ntot_tokens = sum(len(nltk.corpus.gutenberg.words(name)) for name in booknames)
print("Total number of word tokens:", ntot_tokens)
# Out:
# Total number of word tokens: 2621613

# %% [markdown]
# Can we handle all word types or do we need to drop some?

# %%
ntot_types = len(set(w.lower() for bookname in booknames for w in nltk.corpus.gutenberg.words(bookname)))
print("Total number of word types:", ntot_types)
# Out:
# Total number of word types: 42339

# %% [markdown]
# This number of word types is not too high, so we can keep them all in our vocabulary.
#
# Let's look at which words are the most common in the corpus as a whole (**term frequencies** in the entire corpus).

# %%
fdist = nltk.FreqDist(w.lower() for bookname in booknames for w in nltk.corpus.gutenberg.words(bookname))

print("The 100 most common word types in the Gutenberg corpus are:")
for w, f in fdist.most_common(100):
    print(w, f)
# Out:
# The 100 most common word types in the Gutenberg corpus are:
# , 186091
# the 133583
# and 95442
# . 73746
# of 71267
# to 48057
# : 47406
# a 33960
# in 33580
# i 30265
# that 28798
# ; 27329
# he 25857
# it 22303
# his 21402
# ' 19873
# for 19527
# was 18715
# with 17599
# not 17373
# is 16435
# you 16398
# be 16115
# " 15422
# as 14528
# but 13944
# all 13725
# they 13104
# him 13012
# shall 11682
# her 11552
# my 10511
# had 10317
# them 10245
# have 10116
# s 9896
# me 9469
# said 9429
# at 9174
# she 9078
# from 9076
# unto 9010
# this 8915
# - 8850
# which 8775
# on 8596
# lord 8590
# by 8512
# their 7806
# so 7791
# will 7368
# ? 7342
# were 6871
# are 6854
# thou 6759
# there 6380
# when 6330
# or 6325
# one 6218
# no 5846
# what 5792
# out 5771
# ." 5751
# ! 5730
# man 5615
# thy 5609
# -- 5445
# god 5287
# if 5245
# we 5134
# your 5121
# then 5091
# up 5023
# an 4897
# thee 4807
# do 4707
# ," 4702
# now 4677
# ye 4674
# upon 4587
# who 4262
# into 4098
# more 4062
# would 4046
# very 4009
# come 3642
# could 3594
# like 3468
# before 3449
# been 3410
# any 3357
# came 3337
# day 3326
# king 3149
# did 3121
# little 3065
# know 3057
# am 2987
# than 2908
# house 2900

# %% [markdown]
# What about **document frequencies**? For every word type, we count the number of documents (= books) it occurs in:

# %%
from collections import defaultdict

df = defaultdict(int)

for name in booknames:
    for word in set(w.lower() for w in nltk.corpus.gutenberg.words(name)):
        df[word] += 1

# %% [markdown]
# Next we sort the words by their document frequencies:

# %%
df_sorted_words = sorted(df.keys(), key=lambda w: df[w], reverse=True)

# %% [markdown]
# Let's take a look at some words that occur in _all_ the books:

# %%
print("Examples of words that occur in all books:")
for w in df_sorted_words[0:10]:
    print(w, df[w])
# Out:
# Examples of words that occur in all books:
# ' 18
# those 18
# by 18
# then 18
# death 18
# all 18
# foot 18
# alone 18
# fast 18
# where 18

# %% [markdown]
# And some words that only occur in one single book:

# %%
print("Examples of words that occur in only one book:")
for w in df_sorted_words[-10:]:
    print(w, df[w])
# Out:
# Examples of words that occur in only one book:
# democracies 1
# perusing 1
# manhattan 1
# constipation 1
# desolated 1
# venereal 1
# leadballs 1
# palmerin 1
# ejaculate 1
# inauguration 1

# %% [markdown]
# As well as some words that occur in a few books:

# %%
print("Examples of words that occur in some, but not all books:")
for w in df_sorted_words[5000:5010]:
    print(w, df[w])
# Out:
# Examples of words that occur in some, but not all books:
# improving 6
# scrape 6
# rack 6
# clearness 6
# pressure 6
# praising 6
# provocation 6
# writer 6
# pardoned 6
# differ 6

# %% [markdown]
# From the document frequencies we compute the corresponding **inverse document frequency** (idf) values.

# %%
import math

ndocs = len(booknames)
idf = defaultdict(float)

for w in df.keys():
    idf[w] = math.log(ndocs / df[w])

# %% [markdown]
# What do the idf values look like for words that occur in all documents?

# %%
print("Show the IDF values of some words that occur in all books:")
for w in df_sorted_words[0:10]:
    print(w, idf[w])
# Out:
# Show the IDF values of some words that occur in all books:
# ' 0.0
# those 0.0
# by 0.0
# then 0.0
# death 0.0
# all 0.0
# foot 0.0
# alone 0.0
# fast 0.0
# where 0.0

# %% [markdown]
# Or words that occur in one document only?

# %%
print("Show the IDF values of some words that occur in only one book:")
for w in df_sorted_words[-10:]:
    print(w, idf[w])
# Out:
# Show the IDF values of some words that occur in only one book:
# democracies 2.8903717578961645
# perusing 2.8903717578961645
# manhattan 2.8903717578961645
# constipation 2.8903717578961645
# desolated 2.8903717578961645
# venereal 2.8903717578961645
# leadballs 2.8903717578961645
# palmerin 2.8903717578961645
# ejaculate 2.8903717578961645
# inauguration 2.8903717578961645

# %% [markdown]
# Or somewhere in between?

# %%
print("Show the IDF values of some words that occur in some, but not all books:")
for w in df_sorted_words[5000:5010]:
    print(w, idf[w])
# Out:
# Show the IDF values of some words that occur in some, but not all books:
# improving 1.0986122886681098
# scrape 1.0986122886681098
# rack 1.0986122886681098
# clearness 1.0986122886681098
# pressure 1.0986122886681098
# praising 1.0986122886681098
# provocation 1.0986122886681098
# writer 1.0986122886681098
# pardoned 1.0986122886681098
# differ 1.0986122886681098

# %% [markdown]
# For the calculation of the tf-idf scores we also need the *document-specific term frequencies*. Let's look at the 20 most frequent words in each of the documents. Do we see any big differences between the documents?

# %%
for name in booknames:
    fdist = nltk.FreqDist(w.lower() for w in nltk.corpus.gutenberg.words(name))
    print("Most frequent words in {:s}:".format(name))
    for w, f in fdist.most_common(20):
        print(w, f)
    print()
# Out:
# Most frequent words in austen-emma.txt:
# , 11454
# . 6928
# to 5239
# the 5201
# and 4896
# of 4291
# i 3178
# a 3129
# it 2528
# her 2469
# was 2398
# she 2340
# ; 2199
# in 2188
# not 2140
# " 2004
# you 1980
# be 1975
# that 1806
# he 1806
#
# Most frequent words in austen-persuasion.txt:
# , 6750
# the 3329
# to 2808
# and 2801
# . 2741
# of 2570
# a 1595
# in 1389
# was 1337
# ; 1290
# her 1204
# had 1186
# she 1146
# i 1124
# it 1038
# he 961
# be 950
# not 934
# that 882
# as 809
#
# Most frequent words in austen-sense.txt:
# , 9397
# to 4116
# the 4105
# . 3975
# of 3572
# and 3491
# her 2551
# a 2092
# i 2004
# in 1979
# was 1861
# it 1757
# she 1613
# " 1506
# ; 1419
# that 1385
# be 1305
# for 1262
# not 1248
# as 1221
#
# Most frequent words in bible-kjv.txt:
# , 70509
# the 64023
# and 51696
# : 43766
# of 34670
# . 26160
# to 13580
# that 12912
# in 12667
# he 10419
# ; 10084
# shall 9838
# unto 8997
# for 8971
# i 8854
# his 8473
# a 8177
# lord 7964
# they 7376
# be 7013
#
# Most frequent words in blake-poems.txt:
# , 680
# the 439
# and 348
# . 201
# of 146
# in 141
# i 130
# a 128
# to 111
# ' 104
# ; 98
# my 83
# : 75
# with 66
# ? 65
# ! 59
# his 57
# he 56
# is 52
# " 51
#
# Most frequent words in bryant-stories.txt:
# , 3481
# the 3451
# and 2098
# . 1817
# to 1180
# a 1036
# he 1017
# " 900
# of 818
# was 713
# in 641
# it 614
# little 597
# his 551
# i 536
# that 531
# ; 513
# you 462
# ' 457
# said 453
#
# Most frequent words in burgess-busterbrown.txt:
# . 823
# , 822
# he 678
# the 660
# and 516
# to 436
# ' 401
# of 342
# that 308
# it 300
# a 287
# was 274
# buster 229
# had 211
# little 207
# his 184
# t 170
# " 166
# as 163
# in 161
#
# Most frequent words in carroll-alice.txt:
# , 1993
# ' 1731
# the 1642
# and 872
# . 764
# to 729
# a 632
# it 595
# she 553
# i 543
# of 514
# said 462
# you 411
# alice 398
# ,' 397
# in 369
# was 357
# that 315
# !' 278
# as 263
#
# Most frequent words in chesterton-ball.txt:
# the 4965
# , 4547
# . 3589
# and 2667
# of 2555
# a 2262
# " 1751
# to 1580
# in 1407
# he 1328
# that 1168
# it 1137
# you 1066
# i 1000
# was 925
# his 920
# with 815
# is 721
# as 693
# ," 657
#
# Most frequent words in chesterton-brown.txt:
# the 4670
# , 4069
# . 2784
# and 2221
# a 2132
# of 2093
# " 1461
# to 1391
# he 1357
# in 1253
# was 1145
# i 1093
# it 983
# his 965
# that 930
# ' 924
# ; 764
# with 737
# but 692
# you 692
#
# Most frequent words in chesterton-thursday.txt:
# the 3636
# , 3488
# . 2717
# a 1742
# of 1725
# and 1658
# " 1336
# he 1126
# to 1055
# in 923
# i 885
# that 871
# his 810
# you 729
# was 728
# it 717
# with 561
# syme 519
# ," 507
# said 507
#
# Most frequent words in edgeworth-parents.txt:
# , 15219
# the 7728
# . 6945
# to 5220
# and 4983
# " 3880
# of 3745
# i 3657
# ' 3293
# a 3155
# you 2925
# he 2637
# ; 2590
# it 2244
# in 2223
# was 2192
# that 2104
# his 1858
# for 1819
# her 1525
#
# Most frequent words in melville-moby_dick.txt:
# , 18713
# the 14431
# . 6862
# of 6609
# and 6430
# a 4736
# to 4625
# in 4172
# ; 4072
# that 3085
# ' 2684
# - 2552
# his 2530
# it 2522
# i 2127
# he 1896
# but 1818
# s 1802
# as 1741
# is 1725
#
# Most frequent words in milton-paradise.txt:
# , 10198
# and 3395
# the 2968
# ; 2317
# to 2228
# of 2050
# in 1366
# . 1254
# his 1170
# with 1160
# : 748
# or 715
# that 704
# all 700
# from 686
# not 626
# ' 595
# their 595
# i 590
# but 588
#
# Most frequent words in shakespeare-caesar.txt:
# , 2204
# . 1296
# and 627
# the 579
# i 533
# : 499
# to 446
# you 391
# ' 384
# of 354
# ? 296
# that 289
# a 267
# not 257
# is 253
# in 225
# d 215
# my 209
# it 198
# caesar 190
#
# Most frequent words in shakespeare-hamlet.txt:
# , 2892
# . 1886
# the 993
# and 863
# ' 729
# to 685
# of 610
# i 574
# : 565
# you 527
# a 511
# my 502
# ? 459
# it 419
# in 400
# that 377
# ham 337
# is 328
# not 300
# ; 298
#
# Most frequent words in shakespeare-macbeth.txt:
# , 1962
# . 1235
# the 650
# ' 637
# and 546
# : 477
# to 384
# i 348
# of 338
# ? 241
# a 241
# that 238
# d 224
# you 206
# my 203
# in 201
# is 188
# not 165
# it 161
# with 153
#
# Most frequent words in whitman-leaves.txt:
# , 17713
# the 10113
# and 5334
# of 4265
# i 2933
# ' 2362
# to 2244
# in 1875
# - 1774
# . 1769
# d 1579
# you 1537
# a 1293
# with 1250
# ! 1182
# is 1109
# all 1074
# my 1014
# me 1009
# or 1003

# %% [markdown]
# How does it look, when we compute **tf-idf** scores for the words in the documents and compare? We display the 20 top scoring words for each document.

# %%
# For each document (book) ...
for bookname in booknames:
    tf = {}
    tfidf = {}
    fdist = nltk.FreqDist(w.lower() for w in nltk.corpus.gutenberg.words(bookname))

    # For each word in the document ...
    for w, f in fdist.most_common():
        # Compute the term frequency:
        tf[w] = 1 + math.log10(f)
        # ... as well as the tf-idf score:
        tfidf[w] = tf[w] * idf[w]
    
    # Sort the words by tf-idf
    tfidf_sorted_words = sorted(tfidf.keys(), key=lambda w: tfidf[w], reverse=True)
    
    # Show the highest scoring words in this document
    print("Highest tf-idf scoring words in {:s}:".format(bookname))
    for w in tfidf_sorted_words[0:20]:
        print("{:s}: {:.3f} (tf: {:.3f}, idf: {:.3f})".format(w, tfidf[w], tf[w], idf[w]))
    print()
# Out:
# Highest tf-idf scoring words in austen-emma.txt:
# harriet: 10.706 (tf: 3.704, idf: 2.890)
# weston: 10.531 (tf: 3.643, idf: 2.890)
# knightley: 10.376 (tf: 3.590, idf: 2.890)
# elton: 10.363 (tf: 3.585, idf: 2.890)
# woodhouse: 10.103 (tf: 3.496, idf: 2.890)
# fairfax: 9.775 (tf: 3.382, idf: 2.890)
# hartfield: 9.261 (tf: 3.204, idf: 2.890)
# highbury: 8.951 (tf: 3.097, idf: 2.890)
# emma: 8.651 (tf: 3.937, idf: 2.197)
# randalls: 8.539 (tf: 2.954, idf: 2.890)
# cole: 8.051 (tf: 2.785, idf: 2.890)
# goddard: 8.009 (tf: 2.771, idf: 2.890)
# campbell: 7.826 (tf: 2.708, idf: 2.890)
# donwell: 7.776 (tf: 2.690, idf: 2.890)
# dixon: 7.641 (tf: 2.643, idf: 2.890)
# enscombe: 7.389 (tf: 2.556, idf: 2.890)
# churchill: 7.361 (tf: 3.350, idf: 2.197)
# campbells: 6.980 (tf: 2.415, idf: 2.890)
# bates: 6.966 (tf: 3.170, idf: 2.197)
# _she_: 6.880 (tf: 2.380, idf: 2.890)
#
# Highest tf-idf scoring words in austen-persuasion.txt:
# elliot: 10.003 (tf: 3.461, idf: 2.890)
# wentworth: 9.649 (tf: 3.338, idf: 2.890)
# musgrove: 9.000 (tf: 3.114, idf: 2.890)
# uppercross: 8.343 (tf: 2.886, idf: 2.890)
# harville: 8.310 (tf: 2.875, idf: 2.890)
# kellynch: 8.276 (tf: 2.863, idf: 2.890)
# benwick: 8.223 (tf: 2.845, idf: 2.890)
# lyme: 8.168 (tf: 2.826, idf: 2.890)
# croft: 7.987 (tf: 2.763, idf: 2.890)
# musgroves: 7.552 (tf: 2.613, idf: 2.890)
# hayter: 7.457 (tf: 2.580, idf: 2.890)
# dalrymple: 7.073 (tf: 2.447, idf: 2.890)
# russell: 6.966 (tf: 3.170, idf: 2.197)
# crofts: 6.880 (tf: 2.380, idf: 2.890)
# harvilles: 6.519 (tf: 2.255, idf: 2.890)
# henrietta: 6.304 (tf: 2.869, idf: 2.197)
# cobb: 6.203 (tf: 2.146, idf: 2.890)
# carteret: 6.010 (tf: 2.079, idf: 2.890)
# winthrop: 5.900 (tf: 2.041, idf: 2.890)
# shirley: 5.900 (tf: 2.041, idf: 2.890)
#
# Highest tf-idf scoring words in austen-sense.txt:
# elinor: 11.087 (tf: 3.836, idf: 2.890)
# dashwood: 9.831 (tf: 3.401, idf: 2.890)
# jennings: 9.717 (tf: 3.362, idf: 2.890)
# brandon: 9.129 (tf: 3.158, idf: 2.890)
# ferrars: 9.000 (tf: 3.114, idf: 2.890)
# barton: 8.525 (tf: 2.949, idf: 2.890)
# palmer: 8.343 (tf: 2.886, idf: 2.890)
# marianne: 8.246 (tf: 3.753, idf: 2.197)
# norland: 7.874 (tf: 2.724, idf: 2.890)
# dashwoods: 7.389 (tf: 2.556, idf: 2.890)
# willoughby: 7.327 (tf: 3.334, idf: 2.197)
# lucy: 7.184 (tf: 3.270, idf: 2.197)
# delaford: 7.160 (tf: 2.477, idf: 2.890)
# steeles: 7.160 (tf: 2.477, idf: 2.890)
# charlotte: 6.880 (tf: 2.380, idf: 2.890)
# middleton: 6.611 (tf: 3.009, idf: 2.197)
# middletons: 6.586 (tf: 2.279, idf: 2.890)
# allenham: 6.519 (tf: 2.255, idf: 2.890)
# berkeley: 6.447 (tf: 2.230, idf: 2.890)
# combe: 6.371 (tf: 2.204, idf: 2.890)
#
# Highest tf-idf scoring words in bible-kjv.txt:
# levites: 9.894 (tf: 3.423, idf: 2.890)
# cubits: 9.620 (tf: 3.328, idf: 2.890)
# commandments: 9.345 (tf: 3.233, idf: 2.890)
# zion: 9.205 (tf: 3.185, idf: 2.890)
# jeremiah: 9.172 (tf: 3.173, idf: 2.890)
# manasseh: 9.155 (tf: 3.167, idf: 2.890)
# joab: 9.138 (tf: 3.161, idf: 2.890)
# goeth: 9.048 (tf: 3.130, idf: 2.890)
# saith: 9.011 (tf: 4.101, idf: 2.197)
# hezekiah: 8.981 (tf: 3.107, idf: 2.890)
# giveth: 8.961 (tf: 3.100, idf: 2.890)
# samaria: 8.941 (tf: 3.093, idf: 2.890)
# absalom: 8.768 (tf: 3.033, idf: 2.890)
# knoweth: 8.720 (tf: 3.017, idf: 2.890)
# gilead: 8.684 (tf: 3.004, idf: 2.890)
# liveth: 8.620 (tf: 2.982, idf: 2.890)
# doeth: 8.620 (tf: 2.982, idf: 2.890)
# judah: 8.595 (tf: 3.912, idf: 2.197)
# pharisees: 8.496 (tf: 2.940, idf: 2.890)
# edom: 8.482 (tf: 2.934, idf: 2.890)
#
# Highest tf-idf scoring words in blake-poems.txt:
# thel: 6.371 (tf: 2.204, idf: 2.890)
# lyca: 5.648 (tf: 1.954, idf: 2.890)
# blake: 4.631 (tf: 1.602, idf: 2.890)
# answerd: 4.269 (tf: 1.477, idf: 2.890)
# dovelike: 3.760 (tf: 1.301, idf: 2.890)
# watry: 3.760 (tf: 1.301, idf: 2.890)
# bowd: 3.760 (tf: 1.301, idf: 2.890)
# lillys: 3.760 (tf: 1.301, idf: 2.890)
# har: 3.520 (tf: 1.602, idf: 2.197)
# moans: 3.246 (tf: 1.477, idf: 2.197)
# clod: 3.246 (tf: 1.477, idf: 2.197)
# sunflower: 3.246 (tf: 1.477, idf: 2.197)
# weep: 3.049 (tf: 2.380, idf: 1.281)
# vales: 2.939 (tf: 1.954, idf: 1.504)
# :!": 2.890 (tf: 1.000, idf: 2.890)
# wolly: 2.890 (tf: 1.000, idf: 2.890)
# ',": 2.890 (tf: 1.000, idf: 2.890)
# dacre: 2.890 (tf: 1.000, idf: 2.890)
# fen: 2.890 (tf: 1.000, idf: 2.890)
# emily: 2.890 (tf: 1.000, idf: 2.890)
#
# Highest tf-idf scoring words in bryant-stories.txt:
# margery: 8.276 (tf: 2.863, idf: 2.890)
# epaminondas: 7.279 (tf: 2.519, idf: 2.890)
# elsa: 6.770 (tf: 2.342, idf: 2.890)
# jackal: 6.379 (tf: 2.903, idf: 2.197)
# hoppity: 6.371 (tf: 2.204, idf: 2.890)
# zelia: 6.290 (tf: 2.176, idf: 2.890)
# dagda: 6.290 (tf: 2.176, idf: 2.890)
# rollaround: 6.203 (tf: 2.146, idf: 2.890)
# acorn: 6.203 (tf: 2.146, idf: 2.890)
# jester: 6.010 (tf: 2.079, idf: 2.890)
# frode: 6.010 (tf: 2.079, idf: 2.890)
# trundle: 5.900 (tf: 2.041, idf: 2.890)
# brahmin: 5.808 (tf: 2.643, idf: 2.197)
# gottlieb: 5.781 (tf: 2.000, idf: 2.890)
# auntie: 5.648 (tf: 1.954, idf: 2.890)
# piccola: 5.648 (tf: 1.954, idf: 2.890)
# dewdrop: 5.648 (tf: 1.954, idf: 2.890)
# ould: 5.501 (tf: 1.903, idf: 2.890)
# shure: 5.333 (tf: 1.845, idf: 2.890)
# fomorians: 5.333 (tf: 1.845, idf: 2.890)
#
# Highest tf-idf scoring words in burgess-busterbrown.txt:
# blacky: 7.850 (tf: 2.716, idf: 2.890)
# billy: 7.489 (tf: 2.591, idf: 2.890)
# buster: 7.382 (tf: 3.360, idf: 2.197)
# chatterer: 7.117 (tf: 2.462, idf: 2.890)
# mink: 7.073 (tf: 2.447, idf: 2.890)
# jay: 6.931 (tf: 2.398, idf: 2.890)
# reddy: 6.447 (tf: 2.230, idf: 2.890)
# squirrel: 6.110 (tf: 2.114, idf: 2.890)
# footprint: 5.781 (tf: 2.000, idf: 2.890)
# sammy: 5.764 (tf: 2.623, idf: 2.197)
# trout: 5.643 (tf: 2.568, idf: 2.197)
# bobby: 5.333 (tf: 1.845, idf: 2.890)
# unc: 5.140 (tf: 1.778, idf: 2.890)
# grumbly: 4.911 (tf: 1.699, idf: 2.890)
# rumbly: 4.911 (tf: 1.699, idf: 2.890)
# jerry: 4.911 (tf: 1.699, idf: 2.890)
# muskrat: 4.911 (tf: 1.699, idf: 2.890)
# possum: 4.911 (tf: 1.699, idf: 2.890)
# blueberries: 4.911 (tf: 1.699, idf: 2.890)
# otter: 4.851 (tf: 2.708, idf: 1.792)
#
# Highest tf-idf scoring words in carroll-alice.txt:
# duchess: 7.582 (tf: 2.623, idf: 2.890)
# dormouse: 7.521 (tf: 2.602, idf: 2.890)
# alice: 6.450 (tf: 3.600, idf: 1.792)
# gryphon: 6.021 (tf: 2.740, idf: 2.197)
# croquet: 5.648 (tf: 1.954, idf: 2.890)
# whiting: 5.501 (tf: 1.903, idf: 2.890)
# slates: 5.501 (tf: 1.903, idf: 2.890)
# lory: 5.333 (tf: 1.845, idf: 2.890)
# soo: 5.333 (tf: 1.845, idf: 2.890)
# oop: 5.333 (tf: 1.845, idf: 2.890)
# pigs: 5.140 (tf: 1.778, idf: 2.890)
# wow: 5.140 (tf: 1.778, idf: 2.890)
# hatter: 4.924 (tf: 2.748, idf: 1.792)
# hookah: 4.911 (tf: 1.699, idf: 2.890)
# flamingo: 4.911 (tf: 1.699, idf: 2.890)
# dinah: 4.716 (tf: 2.146, idf: 2.197)
# dodo: 4.645 (tf: 2.114, idf: 2.197)
# ann: 4.631 (tf: 1.602, idf: 2.890)
# ,"': 4.631 (tf: 1.602, idf: 2.890)
# ootiful: 4.631 (tf: 1.602, idf: 2.890)
#
# Highest tf-idf scoring words in chesterton-ball.txt:
# turnbull: 10.800 (tf: 3.736, idf: 2.890)
# macian: 10.490 (tf: 3.629, idf: 2.890)
# evan: 9.102 (tf: 3.149, idf: 2.890)
# gutenberg: 7.279 (tf: 2.519, idf: 2.890)
# ebook: 7.073 (tf: 2.447, idf: 2.890)
# madeleine: 6.931 (tf: 2.398, idf: 2.890)
# highlander: 6.826 (tf: 2.362, idf: 2.890)
# ebooks: 6.519 (tf: 2.255, idf: 2.890)
# quayle: 6.447 (tf: 2.230, idf: 2.890)
# hutton: 6.371 (tf: 2.204, idf: 2.890)
# ----": 6.265 (tf: 2.851, idf: 2.197)
# atheist_: 6.203 (tf: 2.146, idf: 2.890)
# /: 6.110 (tf: 2.114, idf: 2.890)
# bert: 6.010 (tf: 2.079, idf: 2.890)
# duellists: 5.648 (tf: 1.954, idf: 2.890)
# madhouse: 5.648 (tf: 1.954, idf: 2.890)
# copyright: 5.501 (tf: 1.903, idf: 2.890)
# donations: 5.501 (tf: 1.903, idf: 2.890)
# _daily: 5.333 (tf: 1.845, idf: 2.890)
# tm: 5.333 (tf: 1.845, idf: 2.890)
#
# Highest tf-idf scoring words in chesterton-brown.txt:
# flambeau: 9.000 (tf: 3.114, idf: 2.890)
# boulnois: 7.850 (tf: 2.716, idf: 2.890)
# muscari: 7.776 (tf: 2.690, idf: 2.890)
# fanshaw: 7.389 (tf: 2.556, idf: 2.890)
# todhunter: 7.279 (tf: 2.519, idf: 2.890)
# hirsch: 7.117 (tf: 2.462, idf: 2.890)
# seymour: 7.117 (tf: 2.462, idf: 2.890)
# harrogate: 7.073 (tf: 2.447, idf: 2.890)
# cutler: 6.980 (tf: 2.415, idf: 2.890)
# kidd: 6.931 (tf: 2.398, idf: 2.890)
# cray: 6.880 (tf: 2.380, idf: 2.890)
# todd: 6.770 (tf: 2.342, idf: 2.890)
# putnam: 6.586 (tf: 2.279, idf: 2.890)
# ezza: 6.371 (tf: 2.204, idf: 2.890)
# carstairs: 6.371 (tf: 2.204, idf: 2.890)
# macnab: 6.290 (tf: 2.176, idf: 2.890)
# dubosc: 6.203 (tf: 2.146, idf: 2.890)
# exmoor: 6.203 (tf: 2.146, idf: 2.890)
# claude: 6.203 (tf: 2.146, idf: 2.890)
# otto: 6.203 (tf: 2.146, idf: 2.890)
# Highest tf-idf scoring words in chesterton-thursday.txt:
# syme: 10.738 (tf: 3.715, idf: 2.890)
# marquis: 8.241 (tf: 2.851, idf: 2.890)
# gogol: 7.423 (tf: 2.568, idf: 2.890)
# anarchists: 7.279 (tf: 2.519, idf: 2.890)
# ratcliffe: 6.931 (tf: 2.398, idf: 2.890)
# renard: 6.712 (tf: 2.322, idf: 2.890)
# gregory: 6.700 (tf: 3.049, idf: 2.197)
# ducroix: 6.110 (tf: 2.114, idf: 2.890)
# anarchist: 5.786 (tf: 2.633, idf: 2.197)
# chairman: 5.648 (tf: 1.954, idf: 2.890)
# witherspoon: 5.648 (tf: 1.954, idf: 2.890)
# dynamiter: 5.501 (tf: 1.903, idf: 2.890)
# anarchism: 5.333 (tf: 1.845, idf: 2.890)
# beastly: 5.333 (tf: 1.845, idf: 2.890)
# eustache: 5.333 (tf: 1.845, idf: 2.890)
# cabs: 5.333 (tf: 1.845, idf: 2.890)
# embankment: 5.140 (tf: 1.778, idf: 2.890)
# secretary: 5.064 (tf: 2.826, idf: 1.792)
# dynamiters: 4.911 (tf: 1.699, idf: 2.890)
# bomb: 4.781 (tf: 2.176, idf: 2.197)
#
# Highest tf-idf scoring words in edgeworth-parents.txt:
# cecilia: 9.374 (tf: 3.243, idf: 2.890)
# piedro: 9.269 (tf: 3.207, idf: 2.890)
# jem: 8.941 (tf: 3.093, idf: 2.890)
# leonora: 8.813 (tf: 3.049, idf: 2.890)
# hal: 8.791 (tf: 3.041, idf: 2.890)
# barbara: 8.566 (tf: 2.964, idf: 2.890)
# rory: 8.511 (tf: 2.944, idf: 2.890)
# loveit: 8.467 (tf: 2.929, idf: 2.890)
# bursal: 8.327 (tf: 2.881, idf: 2.890)
# theresa: 8.168 (tf: 2.826, idf: 2.890)
# tarlton: 8.071 (tf: 2.792, idf: 2.890)
# talb: 7.921 (tf: 2.740, idf: 2.890)
# somers: 7.898 (tf: 2.732, idf: 2.890)
# gresham: 7.801 (tf: 2.699, idf: 2.890)
# burs: 7.669 (tf: 2.653, idf: 2.890)
# pomfret: 7.641 (tf: 2.643, idf: 2.890)
# oakly: 7.521 (tf: 2.602, idf: 2.890)
# somerville: 7.457 (tf: 2.580, idf: 2.890)
# townsend: 7.317 (tf: 2.531, idf: 2.890)
# lightfoot: 7.241 (tf: 2.505, idf: 2.890)
#
# Highest tf-idf scoring words in melville-moby_dick.txt:
# stubb: 9.856 (tf: 3.410, idf: 2.890)
# queequeg: 9.831 (tf: 3.401, idf: 2.890)
# starbuck: 9.529 (tf: 3.297, idf: 2.890)
# pequod: 9.359 (tf: 3.238, idf: 2.890)
# nantucket: 8.620 (tf: 2.982, idf: 2.890)
# moby: 8.452 (tf: 2.924, idf: 2.890)
# pip: 8.293 (tf: 2.869, idf: 2.890)
# whalemen: 8.259 (tf: 2.857, idf: 2.890)
# ahab: 8.148 (tf: 3.708, idf: 2.197)
# tashtego: 7.966 (tf: 2.756, idf: 2.890)
# harpooneers: 7.943 (tf: 2.748, idf: 2.890)
# steelkilt: 7.521 (tf: 2.602, idf: 2.890)
# sperm: 7.443 (tf: 3.387, idf: 2.197)
# forecastle: 7.423 (tf: 2.568, idf: 2.890)
# daggoo: 7.423 (tf: 2.568, idf: 2.890)
# blubber: 7.317 (tf: 2.531, idf: 2.890)
# hammock: 7.279 (tf: 2.519, idf: 2.890)
# harpoons: 7.241 (tf: 2.505, idf: 2.890)
# leeward: 7.117 (tf: 2.462, idf: 2.890)
# shipmates: 7.073 (tf: 2.447, idf: 2.890)
#
# Highest tf-idf scoring words in milton-paradise.txt:
# sovran: 6.447 (tf: 2.230, idf: 2.890)
# angelick: 6.447 (tf: 2.230, idf: 2.890)
# highth: 6.371 (tf: 2.204, idf: 2.890)
# wonderous: 6.110 (tf: 2.114, idf: 2.890)
# empyreal: 5.900 (tf: 2.041, idf: 2.890)
# superiour: 5.900 (tf: 2.041, idf: 2.890)
# ambrosial: 5.648 (tf: 1.954, idf: 2.890)
# aery: 5.648 (tf: 1.954, idf: 2.890)
# heroick: 5.648 (tf: 1.954, idf: 2.890)
# terrour: 5.648 (tf: 1.954, idf: 2.890)
# seraph: 5.501 (tf: 1.903, idf: 2.890)
# erst: 5.501 (tf: 1.903, idf: 2.890)
# inferiour: 5.501 (tf: 1.903, idf: 2.890)
# seised: 5.501 (tf: 1.903, idf: 2.890)
# horrour: 5.333 (tf: 1.845, idf: 2.890)
# shouldst: 5.333 (tf: 1.845, idf: 2.890)
# pursues: 5.140 (tf: 1.778, idf: 2.890)
# scaped: 5.140 (tf: 1.778, idf: 2.890)
# exempt: 5.140 (tf: 1.778, idf: 2.890)
# princedoms: 5.140 (tf: 1.778, idf: 2.890)
#
# Highest tf-idf scoring words in shakespeare-caesar.txt:
# bru: 9.205 (tf: 3.185, idf: 2.890)
# cassi: 8.756 (tf: 3.029, idf: 2.890)
# cassius: 8.467 (tf: 2.929, idf: 2.890)
# caes: 7.489 (tf: 2.591, idf: 2.890)
# brut: 7.423 (tf: 2.568, idf: 2.890)
# caska: 7.279 (tf: 2.519, idf: 2.890)
# luc: 7.073 (tf: 2.447, idf: 2.890)
# brutus: 7.046 (tf: 3.207, idf: 2.197)
# cinna: 6.980 (tf: 2.415, idf: 2.890)
# messala: 6.931 (tf: 2.398, idf: 2.890)
# titinius: 6.826 (tf: 2.362, idf: 2.890)
# octauius: 6.826 (tf: 2.362, idf: 2.890)
# cas: 6.712 (tf: 2.322, idf: 2.890)
# messa: 6.586 (tf: 2.279, idf: 2.890)
# octa: 6.519 (tf: 2.255, idf: 2.890)
# capitoll: 6.447 (tf: 2.230, idf: 2.890)
# decius: 6.447 (tf: 2.230, idf: 2.890)
# por: 6.371 (tf: 2.204, idf: 2.890)
# antony: 6.317 (tf: 2.875, idf: 2.197)
# lucillius: 6.203 (tf: 2.146, idf: 2.890)
#
# Highest tf-idf scoring words in shakespeare-hamlet.txt:
# laer: 8.030 (tf: 2.778, idf: 2.890)
# ophe: 7.943 (tf: 2.748, idf: 2.890)
# pol: 7.776 (tf: 2.690, idf: 2.890)
# rosin: 7.612 (tf: 2.633, idf: 2.890)
# horatio: 7.521 (tf: 2.602, idf: 2.890)
# polon: 7.457 (tf: 2.580, idf: 2.890)
# clo: 7.117 (tf: 2.462, idf: 2.890)
# ophelia: 7.073 (tf: 2.447, idf: 2.890)
# denmarke: 6.651 (tf: 2.301, idf: 2.890)
# polonius: 6.651 (tf: 2.301, idf: 2.890)
# hor: 6.543 (tf: 2.978, idf: 2.197)
# osr: 6.519 (tf: 2.255, idf: 2.890)
# guildensterne: 6.447 (tf: 2.230, idf: 2.890)
# qu: 6.136 (tf: 2.792, idf: 2.197)
# fortinbras: 6.110 (tf: 2.114, idf: 2.890)
# gertrude: 6.110 (tf: 2.114, idf: 2.890)
# reynol: 6.110 (tf: 2.114, idf: 2.890)
# rosincrance: 5.900 (tf: 2.041, idf: 2.890)
# verie: 5.900 (tf: 2.041, idf: 2.890)
# haue: 5.824 (tf: 3.250, idf: 1.792)
#
# Highest tf-idf scoring words in shakespeare-macbeth.txt:
# macb: 9.066 (tf: 3.137, idf: 2.890)
# macbeth: 8.071 (tf: 2.792, idf: 2.890)
# macd: 7.987 (tf: 2.763, idf: 2.890)
# rosse: 7.776 (tf: 2.690, idf: 2.890)
# banquo: 7.489 (tf: 2.591, idf: 2.890)
# lenox: 7.073 (tf: 2.447, idf: 2.890)
# mal: 6.931 (tf: 2.398, idf: 2.890)
# thane: 6.931 (tf: 2.398, idf: 2.890)
# banq: 6.880 (tf: 2.380, idf: 2.890)
# cawdor: 6.712 (tf: 2.322, idf: 2.890)
# doct: 6.651 (tf: 2.301, idf: 2.890)
# macduffe: 6.519 (tf: 2.255, idf: 2.890)
# sey: 6.447 (tf: 2.230, idf: 2.890)
# malc: 6.290 (tf: 2.176, idf: 2.890)
# malcolme: 6.110 (tf: 2.114, idf: 2.890)
# duncan: 5.781 (tf: 2.000, idf: 2.890)
# murth: 5.781 (tf: 2.000, idf: 2.890)
# seyward: 5.781 (tf: 2.000, idf: 2.890)
# macduff: 5.648 (tf: 1.954, idf: 2.890)
# fleans: 5.648 (tf: 1.954, idf: 2.890)
#
# Highest tf-idf scoring words in whitman-leaves.txt:
# }: 10.350 (tf: 3.581, idf: 2.890)
# chants: 7.073 (tf: 2.447, idf: 2.890)
# manhattan: 7.073 (tf: 2.447, idf: 2.890)
# eidolons: 6.712 (tf: 2.322, idf: 2.890)
# bards: 6.651 (tf: 2.301, idf: 2.890)
# libertad: 6.519 (tf: 2.255, idf: 2.890)
# california: 6.447 (tf: 2.230, idf: 2.890)
# colors: 6.447 (tf: 2.230, idf: 2.890)
# mannahatta: 6.371 (tf: 2.204, idf: 2.890)
# absorb: 6.290 (tf: 2.176, idf: 2.890)
# yearning: 6.203 (tf: 2.146, idf: 2.890)
# growths: 6.110 (tf: 2.114, idf: 2.890)
# vigil: 6.110 (tf: 2.114, idf: 2.890)
# bugles: 6.010 (tf: 2.079, idf: 2.890)
# carols: 5.900 (tf: 2.041, idf: 2.890)
# themes: 5.900 (tf: 2.041, idf: 2.890)
# envelop: 5.900 (tf: 2.041, idf: 2.890)
# pennants: 5.900 (tf: 2.041, idf: 2.890)
# myriad: 5.900 (tf: 2.041, idf: 2.890)
# merge: 5.781 (tf: 2.000, idf: 2.890)

# %% [markdown]
# Let's rerun the the tf-idf calculations, but instead of showing the highest scoring words in each document, we will show the scores of some (arbitrarily) selected words:

# %%
selected_words = [ "god", "jesus", "rich", "handsome", "romantic", "secret",
                   "honey", "bear", "ahab", "white", "whale", "alice",
                   "wonderland", "king", "queen", "lazy", "sin", "paradise" ]

for bookname in booknames:
    tf = {}
    tfidf = {}
    fdist = nltk.FreqDist(w.lower() for w in nltk.corpus.gutenberg.words(bookname))
    for w, f in fdist.most_common():
        tf[w] = 1 + math.log10(f)
        tfidf[w] = tf[w] * idf[w]

    print("Tf-idf scores of some selected words in {:s}:".format(bookname))
    for w in selected_words:
        if w in tfidf.keys():
            print("{:s}: {:.3f} (tf: {:.3f}, idf: {:.3f})".format(w, tfidf[w], tf[w], idf[w]))
        else:
            print("{:s}: missing".format(w))
    print()
# Out:
# Tf-idf scores of some selected words in austen-emma.txt:
# god: 0.224 (tf: 1.903, idf: 0.118)
# jesus: missing
# rich: 0.123 (tf: 2.146, idf: 0.057)
# handsome: 1.270 (tf: 2.580, idf: 0.492)
# romantic: 0.944 (tf: 1.000, idf: 0.944)
# secret: 0.000 (tf: 2.322, idf: 0.000)
# honey: missing
# bear: 0.155 (tf: 2.716, idf: 0.057)
# ahab: missing
# white: 0.217 (tf: 1.845, idf: 0.118)
# whale: missing
# alice: missing
# wonderland: missing
# king: 0.237 (tf: 1.301, idf: 0.182)
# queen: 0.182 (tf: 1.000, idf: 0.182)
# lazy: 0.944 (tf: 1.000, idf: 0.944)
# sin: 0.693 (tf: 1.000, idf: 0.693)
# paradise: missing
#
# Tf-idf scores of some selected words in austen-persuasion.txt:
# god: 0.236 (tf: 2.000, idf: 0.118)
# jesus: missing
# rich: 0.117 (tf: 2.041, idf: 0.057)
# handsome: 1.122 (tf: 2.279, idf: 0.492)
# romantic: 0.944 (tf: 1.000, idf: 0.944)
# secret: 0.000 (tf: 1.954, idf: 0.000)
# honey: missing
# bear: 0.133 (tf: 2.322, idf: 0.057)
# ahab: missing
# white: 0.200 (tf: 1.699, idf: 0.118)
# whale: missing
# alice: missing
# wonderland: missing
# king: missing
# queen: 0.182 (tf: 1.000, idf: 0.182)
# lazy: missing
# sin: missing
# paradise: missing
#
# Tf-idf scores of some selected words in austen-sense.txt:
# god: 0.236 (tf: 2.000, idf: 0.118)
# jesus: missing
# rich: 0.126 (tf: 2.204, idf: 0.057)
# handsome: 1.197 (tf: 2.431, idf: 0.492)
# romantic: 1.513 (tf: 1.602, idf: 0.944)
# secret: 0.000 (tf: 2.279, idf: 0.000)
# honey: missing
# bear: 0.135 (tf: 2.362, idf: 0.057)
# ahab: missing
# white: 0.200 (tf: 1.699, idf: 0.118)
# whale: missing
# alice: missing
# wonderland: missing
# king: missing
# queen: 0.182 (tf: 1.000, idf: 0.182)
# lazy: missing
# sin: 0.693 (tf: 1.000, idf: 0.693)
# paradise: missing
#
# Tf-idf scores of some selected words in bible-kjv.txt:
# god: 0.548 (tf: 4.651, idf: 0.118)
# jesus: 5.114 (tf: 3.993, idf: 1.281)
# rich: 0.166 (tf: 2.908, idf: 0.057)
# handsome: missing
# romantic: missing
# secret: 0.000 (tf: 2.833, idf: 0.000)
# honey: 2.229 (tf: 2.748, idf: 0.811)
# bear: 0.190 (tf: 3.332, idf: 0.057)
# ahab: 6.533 (tf: 2.973, idf: 2.197)
# white: 0.339 (tf: 2.875, idf: 0.118)
# whale: 1.623 (tf: 1.477, idf: 1.099)
# alice: missing
# wonderland: missing
# king: 0.803 (tf: 4.405, idf: 0.182)
# queen: 0.498 (tf: 2.732, idf: 0.182)
# lazy: missing
# sin: 2.530 (tf: 3.650, idf: 0.693)
# paradise: 1.198 (tf: 1.477, idf: 0.811)
#
# Tf-idf scores of some selected words in blake-poems.txt:
# god: 0.240 (tf: 2.041, idf: 0.118)
# jesus: 1.281 (tf: 1.000, idf: 1.281)
# rich: 0.057 (tf: 1.000, idf: 0.057)
# handsome: missing
# romantic: missing
# secret: 0.000 (tf: 1.301, idf: 0.000)
# honey: 1.055 (tf: 1.301, idf: 0.811)
# bear: 0.097 (tf: 1.699, idf: 0.057)
# ahab: missing
# white: 0.245 (tf: 2.079, idf: 0.118)
# whale: missing
# alice: missing
# wonderland: missing
# king: 0.182 (tf: 1.000, idf: 0.182)
# queen: 0.310 (tf: 1.699, idf: 0.182)
# lazy: missing
# sin: missing
# paradise: missing
#
# Tf-idf scores of some selected words in bryant-stories.txt:
# god: 0.286 (tf: 2.431, idf: 0.118)
# jesus: missing
# rich: 0.114 (tf: 2.000, idf: 0.057)
# handsome: 0.641 (tf: 1.301, idf: 0.492)
# romantic: missing
# secret: 0.000 (tf: 1.000, idf: 0.000)
# honey: 0.811 (tf: 1.000, idf: 0.811)
# bear: 0.112 (tf: 1.954, idf: 0.057)
# ahab: missing
# white: 0.313 (tf: 2.653, idf: 0.118)
# whale: 2.421 (tf: 2.204, idf: 1.099)
# alice: missing
# wonderland: missing
# king: 0.574 (tf: 3.149, idf: 0.182)
# queen: 0.324 (tf: 1.778, idf: 0.182)
# lazy: 2.082 (tf: 2.204, idf: 0.944)
# sin: missing
# paradise: missing
#
# Tf-idf scores of some selected words in burgess-busterbrown.txt:
# god: missing
# jesus: missing
# rich: missing
# handsome: missing
# romantic: missing
# secret: 0.000 (tf: 1.602, idf: 0.000)
# honey: 1.198 (tf: 1.477, idf: 0.811)
# bear: 0.182 (tf: 3.182, idf: 0.057)
# ahab: missing
# white: missing
# whale: missing
# alice: missing
# wonderland: missing
# king: missing
# queen: missing
# lazy: missing
# sin: missing
# paradise: missing
#
# Tf-idf scores of some selected words in carroll-alice.txt:
# god: missing
# jesus: missing
# rich: 0.057 (tf: 1.000, idf: 0.057)
# handsome: 0.492 (tf: 1.000, idf: 0.492)
# romantic: missing
# secret: 0.000 (tf: 1.000, idf: 0.000)
# honey: missing
# bear: 0.074 (tf: 1.301, idf: 0.057)
# ahab: missing
# white: 0.292 (tf: 2.477, idf: 0.118)
# whale: missing
# alice: 6.450 (tf: 3.600, idf: 1.792)
# wonderland: 3.246 (tf: 1.477, idf: 2.197)
# king: 0.510 (tf: 2.799, idf: 0.182)
# queen: 0.524 (tf: 2.875, idf: 0.182)
# lazy: 0.944 (tf: 1.000, idf: 0.944)
# sin: missing
# paradise: missing
#
# Tf-idf scores of some selected words in chesterton-ball.txt:
# god: 0.371 (tf: 3.146, idf: 0.118)
# jesus: 1.281 (tf: 1.000, idf: 1.281)
# rich: 0.105 (tf: 1.845, idf: 0.057)
# handsome: 0.837 (tf: 1.699, idf: 0.492)
# romantic: 1.513 (tf: 1.602, idf: 0.944)
# secret: 0.000 (tf: 1.845, idf: 0.000)
# honey: missing
# bear: 0.092 (tf: 1.602, idf: 0.057)
# ahab: missing
# white: 0.328 (tf: 2.785, idf: 0.118)
# whale: 1.429 (tf: 1.301, idf: 1.099)
# alice: missing
# wonderland: missing
# king: 0.365 (tf: 2.000, idf: 0.182)
# queen: 0.292 (tf: 1.602, idf: 0.182)
# lazy: 0.944 (tf: 1.000, idf: 0.944)
# sin: 1.279 (tf: 1.845, idf: 0.693)
# paradise: 1.299 (tf: 1.602, idf: 0.811)
#
# Tf-idf scores of some selected words in chesterton-brown.txt:
# god: 0.278 (tf: 2.362, idf: 0.118)
# jesus: missing
# rich: 0.102 (tf: 1.778, idf: 0.057)
# handsome: 1.005 (tf: 2.041, idf: 0.492)
# romantic: 1.964 (tf: 2.079, idf: 0.944)
# secret: 0.000 (tf: 2.462, idf: 0.000)
# honey: missing
# bear: 0.105 (tf: 1.845, idf: 0.057)
# ahab: missing
# white: 0.323 (tf: 2.740, idf: 0.118)
# whale: missing
# alice: missing
# wonderland: missing
# king: 0.423 (tf: 2.322, idf: 0.182)
# queen: 0.269 (tf: 1.477, idf: 0.182)
# lazy: 0.944 (tf: 1.000, idf: 0.944)
# sin: missing
# paradise: 1.442 (tf: 1.778, idf: 0.811)
#
# Tf-idf scores of some selected words in chesterton-thursday.txt:
# god: 0.301 (tf: 2.556, idf: 0.118)
# jesus: missing
# rich: 0.119 (tf: 2.079, idf: 0.057)
# handsome: 0.492 (tf: 1.000, idf: 0.492)
# romantic: 0.944 (tf: 1.000, idf: 0.944)
# secret: 0.000 (tf: 2.255, idf: 0.000)
# honey: missing
# bear: 0.057 (tf: 1.000, idf: 0.057)
# ahab: missing
# white: 0.322 (tf: 2.732, idf: 0.118)
# whale: missing
# alice: 1.792 (tf: 1.000, idf: 1.792)
# wonderland: 2.197 (tf: 1.000, idf: 2.197)
# king: 0.324 (tf: 1.778, idf: 0.182)
# queen: 0.237 (tf: 1.301, idf: 0.182)
# lazy: missing
# sin: 1.024 (tf: 1.477, idf: 0.693)
# paradise: 1.198 (tf: 1.477, idf: 0.811)
#
# Tf-idf scores of some selected words in edgeworth-parents.txt:
# god: 0.271 (tf: 2.301, idf: 0.118)
# jesus: missing
# rich: 0.141 (tf: 2.462, idf: 0.057)
# handsome: 1.111 (tf: 2.255, idf: 0.492)
# romantic: missing
# secret: 0.000 (tf: 2.398, idf: 0.000)
# honey: 1.809 (tf: 2.230, idf: 0.811)
# bear: 0.137 (tf: 2.398, idf: 0.057)
# ahab: missing
# white: 0.328 (tf: 2.785, idf: 0.118)
# whale: missing
# alice: 2.331 (tf: 1.301, idf: 1.792)
# wonderland: missing
# king: 0.397 (tf: 2.176, idf: 0.182)
# queen: 0.420 (tf: 2.301, idf: 0.182)
# lazy: 2.130 (tf: 2.255, idf: 0.944)
# sin: 0.902 (tf: 1.301, idf: 0.693)
# paradise: 1.055 (tf: 1.301, idf: 0.811)
#
# Tf-idf scores of some selected words in melville-moby_dick.txt:
# god: 0.375 (tf: 3.182, idf: 0.118)
# jesus: 1.281 (tf: 1.000, idf: 1.281)
# rich: 0.109 (tf: 1.903, idf: 0.057)
# handsome: 0.727 (tf: 1.477, idf: 0.492)
# romantic: 1.743 (tf: 1.845, idf: 0.944)
# secret: 0.000 (tf: 2.380, idf: 0.000)
# honey: 1.198 (tf: 1.477, idf: 0.811)
# bear: 0.147 (tf: 2.568, idf: 0.057)
# ahab: 8.148 (tf: 3.708, idf: 2.197)
# white: 0.406 (tf: 3.449, idf: 0.118)
# whale: 4.492 (tf: 4.088, idf: 1.099)
# alice: missing
# wonderland: missing
# king: 0.512 (tf: 2.806, idf: 0.182)
# queen: 0.411 (tf: 2.255, idf: 0.182)
# lazy: 1.395 (tf: 1.477, idf: 0.944)
# sin: 1.319 (tf: 1.903, idf: 0.693)
# paradise: 1.378 (tf: 1.699, idf: 0.811)
#
# Tf-idf scores of some selected words in milton-paradise.txt:
# god: 0.402 (tf: 3.415, idf: 0.118)
# jesus: 1.667 (tf: 1.301, idf: 1.281)
# rich: 0.114 (tf: 2.000, idf: 0.057)
# handsome: missing
# romantic: missing
# secret: 0.000 (tf: 2.146, idf: 0.000)
# honey: 0.811 (tf: 1.000, idf: 0.811)
# bear: 0.136 (tf: 2.380, idf: 0.057)
# ahab: missing
# white: 0.174 (tf: 1.477, idf: 0.118)
# whale: missing
# alice: missing
# wonderland: missing
# king: 0.489 (tf: 2.681, idf: 0.182)
# queen: 0.310 (tf: 1.699, idf: 0.182)
# lazy: missing
# sin: 1.858 (tf: 2.681, idf: 0.693)
# paradise: 2.216 (tf: 2.732, idf: 0.811)
#
# Tf-idf scores of some selected words in shakespeare-caesar.txt:
# god: 0.174 (tf: 1.477, idf: 0.118)
# jesus: missing
# rich: 0.074 (tf: 1.301, idf: 0.057)
# handsome: missing
# romantic: missing
# secret: 0.000 (tf: 1.301, idf: 0.000)
# honey: missing
# bear: missing
# ahab: missing
# white: missing
# whale: missing
# alice: missing
# wonderland: missing
# king: 0.292 (tf: 1.602, idf: 0.182)
# queen: missing
# lazy: missing
# sin: missing
# paradise: missing
# Tf-idf scores of some selected words in shakespeare-hamlet.txt:
# god: 0.284 (tf: 2.415, idf: 0.118)
# jesus: missing
# rich: 0.084 (tf: 1.477, idf: 0.057)
# handsome: missing
# romantic: missing
# secret: 0.000 (tf: 1.602, idf: 0.000)
# honey: missing
# bear: 0.057 (tf: 1.000, idf: 0.057)
# ahab: missing
# white: 0.189 (tf: 1.602, idf: 0.118)
# whale: 1.429 (tf: 1.301, idf: 1.099)
# alice: missing
# wonderland: missing
# king: 0.590 (tf: 3.236, idf: 0.182)
# queen: 0.347 (tf: 1.903, idf: 0.182)
# lazy: missing
# sin: missing
# paradise: missing
#
# Tf-idf scores of some selected words in shakespeare-macbeth.txt:
# god: 0.253 (tf: 2.146, idf: 0.118)
# jesus: missing
# rich: 0.057 (tf: 1.000, idf: 0.057)
# handsome: missing
# romantic: missing
# secret: 0.000 (tf: 1.477, idf: 0.000)
# honey: missing
# bear: 0.057 (tf: 1.000, idf: 0.057)
# ahab: missing
# white: 0.118 (tf: 1.000, idf: 0.118)
# whale: missing
# alice: missing
# wonderland: missing
# king: 0.500 (tf: 2.740, idf: 0.182)
# queen: missing
# lazy: missing
# sin: missing
# paradise: missing
#
# Tf-idf scores of some selected words in whitman-leaves.txt:
# god: 0.339 (tf: 2.875, idf: 0.118)
# jesus: missing
# rich: 0.140 (tf: 2.447, idf: 0.057)
# handsome: 0.909 (tf: 1.845, idf: 0.492)
# romantic: missing
# secret: 0.000 (tf: 2.114, idf: 0.000)
# honey: 1.442 (tf: 1.778, idf: 0.811)
# bear: 0.136 (tf: 2.380, idf: 0.057)
# ahab: missing
# white: 0.347 (tf: 2.949, idf: 0.118)
# whale: 1.867 (tf: 1.699, idf: 1.099)
# alice: missing
# wonderland: missing
# king: 0.292 (tf: 1.602, idf: 0.182)
# queen: 0.237 (tf: 1.301, idf: 0.182)
# lazy: missing
# sin: 1.178 (tf: 1.699, idf: 0.693)
# paradise: 1.442 (tf: 1.778, idf: 0.811)

# %% [markdown]
# Does this make sense?
#
# How come the tf-idf score is zero for some words? What might be the consequences of this? Are there any weaknesses in this approach?
